# %% [markdown]
# # Reading dataset to python environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel(r'C:\Users\Ananthan\iris.xls')

# %% [markdown]
# # Displaying columns

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Mean of each column

# %%
data1=data.mean(axis=0)
# Out:
# C:\Users\Ananthan\AppData\Local\Temp/ipykernel_14704/1678400396.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data1=data.mean(axis=0)

# %%
print(data1)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for null values

# %%
data2=data.isna()

# %%
print(data2)
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Data visualisations

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(6,6))
plt.hist(data['PL'])
plt.title('Petal Length')
plt.xlabel('Petal Length')
plt.ylabel('Frequency');
plt.figure()
plt.hist(data['PW'])
plt.title('Petal Width')
plt.xlabel('Petal Width')
plt.ylabel('Frequency');
plt.figure()
plt.hist(data['SL'])
plt.title('Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency');
plt.figure()
plt.hist(data['SW'])
plt.title('Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x='PL', y='PW', hue='Classification', data=data)
plt.title('Scatter Plot')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width');

# %%
sns.scatterplot(x='SL', y='SW', hue='Classification', data=data)
plt.title('Scatter Plot')
plt.xlabel('Sepal Length')
plt.ylabel;('Sepal Width')
# Out:
# 'Sepal Width'

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(data)
